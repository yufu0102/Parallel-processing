# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

FILE_PATH = 'glass.csv'                                # csv path
raw_data = pd.read_csv(FILE_PATH)						    

print("Raw data loaded successfully...\n")
#------------------------------------------------------------------------------
# 參數

Y_LABEL = 'Type'                                   		    	# 結果label
KEYS = [i for i in raw_data.keys().tolist() if i != Y_LABEL]	# 用來運算預測的key
N_INSTANCES = raw_data.shape[0]                     			# Number of instances
N_INPUT = raw_data.shape[1] - 1                     			# Input size
N_CLASSES = 8                                                   # 類型數
TEST_SIZE = 0.1                                    			    # 測試數
TRAIN_SIZE = int(N_INSTANCES * (1 - TEST_SIZE))     			# 訓練大小
LEARNING_RATE = 0.001                              			    # 學習rate
TRAINING_EPOCHS = 350                               			# epochs
BATCH_SIZE = 100                                    			# Batch size
DISPLAY_STEP = 1                                    			# Display progress each x epochs
HIDDEN_SIZE = 1000	                                   	    	# Number of hidden neurons
STDDEV = 0.1                                        			# Standard deviation (for weights random init)
RANDOM_STATE = 100 									            # Random state for train_test_split

#------------------------------------------------------------------------------
# Loading data

# Load data
data = raw_data[KEYS].get_values()                  			# X data
labels = raw_data[Y_LABEL].get_values()             			# y data
# One hot encoding for labels
labels_ = np.zeros((N_INSTANCES, N_CLASSES))
labels_[np.arange(N_INSTANCES), labels] = 1

# Train-test split
data_train, data_test, labels_train, labels_test = train_test_split(data,
                                                                    labels_,
                                                                    test_size = TEST_SIZE,
                                                                    random_state = RANDOM_STATE)

print("讀取完畢 檔案分割成功\n")
#------------------------------------------------------------------------------
#神經網路架構

# Tf placeholders
X = tf.placeholder(tf.float32, [None, N_INPUT])
y = tf.placeholder(tf.float32, [None, N_CLASSES])
dropout_keep_prob = tf.placeholder(tf.float32)

# 自定義層次函數
def layer(output_dim, input_dim, inputs, activation = None):
    W = tf.Variable(tf.random_normal([input_dim, output_dim]))
    b = tf.Variable(tf.random_normal([1, output_dim]))
    XWb = tf.matmul(inputs, W) + b
    if activation is None:
        outputs = XWb
    else:
        outputs = activation(XWb)
    return outputs

# Build model
h1 = layer(output_dim = HIDDEN_SIZE, input_dim = N_INPUT, inputs = X, activation = tf.nn.tanh)
h2 = layer(output_dim = HIDDEN_SIZE, input_dim = HIDDEN_SIZE, inputs = h1, activation = tf.nn.tanh)
h3 = layer(output_dim = HIDDEN_SIZE, input_dim = HIDDEN_SIZE, inputs = h2, activation = tf.nn.tanh)
pred = layer(output_dim = N_CLASSES, input_dim = HIDDEN_SIZE, inputs = h3, activation = None)
#loss以及優化公式
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = pred, labels = y))
optimizer = tf.train.AdamOptimizer(learning_rate = LEARNING_RATE).minimize(cost)

#計算正確率
correct_prediction = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

#初始化
init = tf.initialize_all_variables()

print("開始訓練\n")
#------------------------------------------------------------------------------
# Training

sess = tf.Session()
sess.run(init)
loss_list = []
epoch_list = []
accuracy_list = []

#訓練迴圈
for epoch in range(TRAINING_EPOCHS):
    avg_cost = 0.
    total_batch = int(data_train.shape[0] / BATCH_SIZE)
    #batches
    for i in range(total_batch):
        randidx = np.random.randint(int(TRAIN_SIZE), size = BATCH_SIZE)
        batch_xs = data_train[randidx, :]
        batch_ys = labels_train[randidx, :]
        #優化
        sess.run(optimizer, feed_dict={X: batch_xs, y: batch_ys, dropout_keep_prob: 0.9})
        #平均loss
        avg_cost += sess.run(cost, feed_dict={X: batch_xs, y: batch_ys, dropout_keep_prob:1.})/total_batch
    #log
    if epoch % DISPLAY_STEP == 0:
        print ("Epoch: %03d/%03d cost: %.9f" % (epoch, TRAINING_EPOCHS, avg_cost))
        train_acc = sess.run(accuracy, feed_dict={X: batch_xs, y: batch_ys, dropout_keep_prob:1.})
        print ("Training accuracy: %.3f" % (train_acc))
        epoch_list.append(epoch)
        loss_list.append(avg_cost)
        accuracy_list.append(train_acc)



print ("訓練完成")
print("開始測試...\n")
#------------------------------------------------------------------------------
# Testing

test_acc = sess.run(accuracy, feed_dict={X: data_test, y: labels_test, dropout_keep_prob:1.})
print ("Test accuracy: %.3f" % (test_acc))

sess.close()
print("Session closed!")

#顯示曲線圖
#%matplotlib inline
fig = plt.gcf()
fig.set_size_inches(5, 3)
plt.plot(epoch_list, loss_list, label = 'loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc = 'upper right')
plt.show()

fig = plt.gcf()
fig.set_size_inches(5, 3)
plt.plot(epoch_list, accuracy_list, label = 'accuracy')

plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy'], loc = 'upper left')
plt.show()
# Out:
# Raw data loaded successfully...
#
# 讀取完畢 檔案分割成功
#
# 開始訓練
#
# Epoch: 000/350 cost: 26.355628967
# Training accuracy: 0.300
# Epoch: 001/350 cost: 17.221557617
# Training accuracy: 0.510
# Epoch: 002/350 cost: 15.795607567
# Training accuracy: 0.380
# Epoch: 003/350 cost: 9.814291954
# Training accuracy: 0.460
# Epoch: 004/350 cost: 5.092673779
# Training accuracy: 0.610
# Epoch: 005/350 cost: 6.561107159
# Training accuracy: 0.630
# Epoch: 006/350 cost: 2.604740381
# Training accuracy: 0.700
# Epoch: 007/350 cost: 3.260846138
# Training accuracy: 0.710
# Epoch: 008/350 cost: 2.668932438
# Training accuracy: 0.700
# Epoch: 009/350 cost: 2.362369299
# Training accuracy: 0.650
# Epoch: 010/350 cost: 1.883222818
# Training accuracy: 0.760
# Epoch: 011/350 cost: 2.333899975
# Training accuracy: 0.710
# Epoch: 012/350 cost: 1.523676753
# Training accuracy: 0.690
# Epoch: 013/350 cost: 2.248526335
# Training accuracy: 0.770
# Epoch: 014/350 cost: 2.169448614
# Training accuracy: 0.760
# Epoch: 015/350 cost: 1.489779711
# Training accuracy: 0.740
# Epoch: 016/350 cost: 1.627605319
# Training accuracy: 0.760
# Epoch: 017/350 cost: 1.681962013
# Training accuracy: 0.730
# Epoch: 018/350 cost: 0.840791225
# Training accuracy: 0.800
# Epoch: 019/350 cost: 0.456381917
# Training accuracy: 0.870
# Epoch: 020/350 cost: 1.124508619
# Training accuracy: 0.810
# Epoch: 021/350 cost: 0.666413128
# Training accuracy: 0.890
# Epoch: 022/350 cost: 0.981675506
# Training accuracy: 0.810
# Epoch: 023/350 cost: 1.094242811
# Training accuracy: 0.820
# Epoch: 024/350 cost: 0.699779034
# Training accuracy: 0.800
# Epoch: 025/350 cost: 0.847995937
# Training accuracy: 0.790
# Epoch: 026/350 cost: 0.943070531
# Training accuracy: 0.830
# Epoch: 027/350 cost: 0.771339357
# Training accuracy: 0.840
# Epoch: 028/350 cost: 0.561849475
# Training accuracy: 0.860
# Epoch: 029/350 cost: 0.480867237
# Training accuracy: 0.840
# Epoch: 030/350 cost: 0.498712450
# Training accuracy: 0.890
# Epoch: 031/350 cost: 0.370798379
# Training accuracy: 0.870
# Epoch: 032/350 cost: 0.321464360
# Training accuracy: 0.890
# Epoch: 033/350 cost: 0.336965114
# Training accuracy: 0.920
# Epoch: 034/350 cost: 0.435252577
# Training accuracy: 0.910
# Epoch: 035/350 cost: 0.404687464
# Training accuracy: 0.880
# Epoch: 036/350 cost: 0.331817865
# Training accuracy: 0.890
# Epoch: 037/350 cost: 0.327341646
# Training accuracy: 0.890
# Epoch: 038/350 cost: 0.485441774
# Training accuracy: 0.880
# Epoch: 039/350 cost: 0.231847301
# Training accuracy: 0.920
# Epoch: 040/350 cost: 0.400790125
# Training accuracy: 0.870
# Epoch: 041/350 cost: 0.407655984
# Training accuracy: 0.850
# Epoch: 042/350 cost: 0.423694104
# Training accuracy: 0.870
# Epoch: 043/350 cost: 0.470349580
# Training accuracy: 0.870
# Epoch: 044/350 cost: 0.292145252
# Training accuracy: 0.890
# Epoch: 045/350 cost: 0.328553617
# Training accuracy: 0.890
# Epoch: 046/350 cost: 0.187464938
# Training accuracy: 0.950
# Epoch: 047/350 cost: 0.365989238
# Training accuracy: 0.890
# Epoch: 048/350 cost: 0.367237628
# Training accuracy: 0.870
# Epoch: 049/350 cost: 0.213723466
# Training accuracy: 0.910
# Epoch: 050/350 cost: 0.272781432
# Training accuracy: 0.910
# Epoch: 051/350 cost: 0.306659907
# Training accuracy: 0.900
# Epoch: 052/350 cost: 0.160818160
# Training accuracy: 0.960
# Epoch: 053/350 cost: 0.275995642
# Training accuracy: 0.860
# Epoch: 054/350 cost: 0.353571206
# Training accuracy: 0.900
# Epoch: 055/350 cost: 0.281068027
# Training accuracy: 0.920
# Epoch: 056/350 cost: 0.289990872
# Training accuracy: 0.920
# Epoch: 057/350 cost: 0.507202566
# Training accuracy: 0.800
# Epoch: 058/350 cost: 0.219196931
# Training accuracy: 0.910
# Epoch: 059/350 cost: 0.332135171
# Training accuracy: 0.860
# Epoch: 060/350 cost: 0.248545572
# Training accuracy: 0.870
# Epoch: 061/350 cost: 0.252476960
# Training accuracy: 0.930
# Epoch: 062/350 cost: 0.125926450
# Training accuracy: 0.910
# Epoch: 063/350 cost: 0.382847399
# Training accuracy: 0.910
# Epoch: 064/350 cost: 0.356617510
# Training accuracy: 0.870
# Epoch: 065/350 cost: 0.120662488
# Training accuracy: 0.960
# Epoch: 066/350 cost: 0.354172051
# Training accuracy: 0.890
# Epoch: 067/350 cost: 0.474914104
# Training accuracy: 0.830
# Epoch: 068/350 cost: 0.256568819
# Training accuracy: 0.940
# Epoch: 069/350 cost: 0.752207100
# Training accuracy: 0.810
# Epoch: 070/350 cost: 0.755331278
# Training accuracy: 0.790
# Epoch: 071/350 cost: 0.515653372
# Training accuracy: 0.880
# Epoch: 072/350 cost: 0.326815903
# Training accuracy: 0.940
# Epoch: 073/350 cost: 1.005897164
# Training accuracy: 0.760
# Epoch: 074/350 cost: 0.764681160
# Training accuracy: 0.840
# Epoch: 075/350 cost: 0.488907933
# Training accuracy: 0.890
# Epoch: 076/350 cost: 0.861512244
# Training accuracy: 0.810
# Epoch: 077/350 cost: 0.699837744
# Training accuracy: 0.810
# Epoch: 078/350 cost: 0.438848138
# Training accuracy: 0.850
# Epoch: 079/350 cost: 0.397419751
# Training accuracy: 0.880
# Epoch: 080/350 cost: 0.536083817
# Training accuracy: 0.850
# Epoch: 081/350 cost: 0.404512435
# Training accuracy: 0.890
# Epoch: 082/350 cost: 0.275210112
# Training accuracy: 0.920
# Epoch: 083/350 cost: 0.671433032
# Training accuracy: 0.810
# Epoch: 084/350 cost: 0.395478934
# Training accuracy: 0.850
# Epoch: 085/350 cost: 0.404984504
# Training accuracy: 0.890
# Epoch: 086/350 cost: 0.539380550
# Training accuracy: 0.830
# Epoch: 087/350 cost: 0.224382192
# Training accuracy: 0.920
# Epoch: 088/350 cost: 0.502805948
# Training accuracy: 0.860
# Epoch: 089/350 cost: 0.337947428
# Training accuracy: 0.900
# Epoch: 090/350 cost: 0.438216448
# Training accuracy: 0.830
# Epoch: 091/350 cost: 0.409972489
# Training accuracy: 0.850
# Epoch: 092/350 cost: 0.447534114
# Training accuracy: 0.870
# Epoch: 093/350 cost: 0.477073163
# Training accuracy: 0.880
# Epoch: 094/350 cost: 0.215632170
# Training accuracy: 0.920
# Epoch: 095/350 cost: 0.443067551
# Training accuracy: 0.850
# Epoch: 096/350 cost: 0.159062669
# Training accuracy: 0.930
# Epoch: 097/350 cost: 0.279726297
# Training accuracy: 0.920
# Epoch: 098/350 cost: 0.233358115
# Training accuracy: 0.890
# Epoch: 099/350 cost: 0.336109072
# Training accuracy: 0.880
# Epoch: 100/350 cost: 0.289709091
# Training accuracy: 0.940
# Epoch: 101/350 cost: 0.286668181
# Training accuracy: 0.870
# Epoch: 102/350 cost: 0.290785015
# Training accuracy: 0.870
# Epoch: 103/350 cost: 0.246665016
# Training accuracy: 0.920
# Epoch: 104/350 cost: 0.305005252
# Training accuracy: 0.900
# Epoch: 105/350 cost: 0.169696391
# Training accuracy: 0.950
# Epoch: 106/350 cost: 0.315994978
# Training accuracy: 0.890
# Epoch: 107/350 cost: 0.161557928
# Training accuracy: 0.970
# Epoch: 108/350 cost: 0.452430278
# Training accuracy: 0.840
# Epoch: 109/350 cost: 0.293443114
# Training accuracy: 0.940
# Epoch: 110/350 cost: 0.162665665
# Training accuracy: 0.940
# Epoch: 111/350 cost: 0.182711959
# Training accuracy: 0.900
# Epoch: 112/350 cost: 0.298269391
# Training accuracy: 0.880
# Epoch: 113/350 cost: 0.238143429
# Training accuracy: 0.930
# Epoch: 114/350 cost: 0.147296757
# Training accuracy: 0.960
# Epoch: 115/350 cost: 0.237101495
# Training accuracy: 0.930
# Epoch: 116/350 cost: 0.327561200
# Training accuracy: 0.900
# Epoch: 117/350 cost: 0.410897136
# Training accuracy: 0.880
# Epoch: 118/350 cost: 0.144668803
# Training accuracy: 0.930
# Epoch: 119/350 cost: 0.139764160
# Training accuracy: 0.950
# Epoch: 120/350 cost: 0.204513609
# Training accuracy: 0.890
# Epoch: 121/350 cost: 0.375967860
# Training accuracy: 0.890
# Epoch: 122/350 cost: 0.086884536
# Training accuracy: 0.960
# Epoch: 123/350 cost: 0.471714675
# Training accuracy: 0.860
# Epoch: 124/350 cost: 0.239733398
# Training accuracy: 0.900
# Epoch: 125/350 cost: 0.229678437
# Training accuracy: 0.940
# Epoch: 126/350 cost: 0.076691180
# Training accuracy: 0.980
# Epoch: 127/350 cost: 0.297563106
# Training accuracy: 0.890
# Epoch: 128/350 cost: 0.170713991
# Training accuracy: 0.960
# Epoch: 129/350 cost: 0.229053348
# Training accuracy: 0.930
# Epoch: 130/350 cost: 0.237618968
# Training accuracy: 0.900
# Epoch: 131/350 cost: 0.245034769
# Training accuracy: 0.880
# Epoch: 132/350 cost: 0.123028256
# Training accuracy: 0.940
# Epoch: 133/350 cost: 0.135765731
# Training accuracy: 0.940
# Epoch: 134/350 cost: 0.188271746
# Training accuracy: 0.910
# Epoch: 135/350 cost: 0.174774736
# Training accuracy: 0.940
# Epoch: 136/350 cost: 0.105417110
# Training accuracy: 0.960
# Epoch: 137/350 cost: 0.136649668
# Training accuracy: 0.940
# Epoch: 138/350 cost: 0.199627072
# Training accuracy: 0.930
# Epoch: 139/350 cost: 0.122457221
# Training accuracy: 0.970
# Epoch: 140/350 cost: 0.162153244
# Training accuracy: 0.960
# Epoch: 141/350 cost: 0.095271900
# Training accuracy: 0.940
# Epoch: 142/350 cost: 0.227890879
# Training accuracy: 0.900
# Epoch: 143/350 cost: 0.369349599
# Training accuracy: 0.900
# Epoch: 144/350 cost: 0.247431576
# Training accuracy: 0.920
# Epoch: 145/350 cost: 0.297590137
# Training accuracy: 0.900
# Epoch: 146/350 cost: 0.169221938
# Training accuracy: 0.950
# Epoch: 147/350 cost: 0.294503897
# Training accuracy: 0.930
# Epoch: 148/350 cost: 0.182914540
# Training accuracy: 0.920
# Epoch: 149/350 cost: 0.115897678
# Training accuracy: 0.960
# Epoch: 150/350 cost: 0.191686749
# Training accuracy: 0.910
# Epoch: 151/350 cost: 0.351957351
# Training accuracy: 0.870
# Epoch: 152/350 cost: 0.146732926
# Training accuracy: 0.940
# Epoch: 153/350 cost: 0.290272593
# Training accuracy: 0.880
# Epoch: 154/350 cost: 0.243377566
# Training accuracy: 0.900
# Epoch: 155/350 cost: 0.223255679
# Training accuracy: 0.930
# Epoch: 156/350 cost: 0.246482417
# Training accuracy: 0.890
# Epoch: 157/350 cost: 0.218885094
# Training accuracy: 0.900
# Epoch: 158/350 cost: 0.146726117
# Training accuracy: 0.960
# Epoch: 159/350 cost: 0.235414922
# Training accuracy: 0.880
# Epoch: 160/350 cost: 0.171143651
# Training accuracy: 0.950
# Epoch: 161/350 cost: 0.300556481
# Training accuracy: 0.900
# Epoch: 162/350 cost: 0.087851554
# Training accuracy: 0.970
# Epoch: 163/350 cost: 0.217078820
# Training accuracy: 0.890
# Epoch: 164/350 cost: 0.328527957
# Training accuracy: 0.880
# Epoch: 165/350 cost: 0.187071502
# Training accuracy: 0.920
# Epoch: 166/350 cost: 0.158097699
# Training accuracy: 0.950
# Epoch: 167/350 cost: 0.109545499
# Training accuracy: 0.970
# Epoch: 168/350 cost: 0.181415811
# Training accuracy: 0.900
# Epoch: 169/350 cost: 0.335252374
# Training accuracy: 0.930
# Epoch: 170/350 cost: 0.215491623
# Training accuracy: 0.870
# Epoch: 171/350 cost: 0.249085605
# Training accuracy: 0.910
# Epoch: 172/350 cost: 0.342209131
# Training accuracy: 0.900
# Epoch: 173/350 cost: 0.167611137
# Training accuracy: 0.940
# Epoch: 174/350 cost: 0.247522637
# Training accuracy: 0.950
# Epoch: 175/350 cost: 0.108273335
# Training accuracy: 0.950
# Epoch: 176/350 cost: 0.137623399
# Training accuracy: 0.920
# Epoch: 177/350 cost: 0.238689467
# Training accuracy: 0.930
# Epoch: 178/350 cost: 0.139616936
# Training accuracy: 0.970
# Epoch: 179/350 cost: 0.171723410
# Training accuracy: 0.940
# Epoch: 180/350 cost: 0.118386462
# Training accuracy: 0.950
# Epoch: 181/350 cost: 0.111924313
# Training accuracy: 0.960
# Epoch: 182/350 cost: 0.180720255
# Training accuracy: 0.920
# Epoch: 183/350 cost: 0.166078925
# Training accuracy: 0.960
# Epoch: 184/350 cost: 0.228128359
# Training accuracy: 0.920
# Epoch: 185/350 cost: 0.204907671
# Training accuracy: 0.920
# Epoch: 186/350 cost: 0.119441584
# Training accuracy: 0.980
# Epoch: 187/350 cost: 0.188497975
# Training accuracy: 0.910
# Epoch: 188/350 cost: 0.180082932
# Training accuracy: 0.870
# Epoch: 189/350 cost: 0.094510622
# Training accuracy: 0.970
# Epoch: 190/350 cost: 0.132976398
# Training accuracy: 0.930
# Epoch: 191/350 cost: 0.143714726
# Training accuracy: 0.960
# Epoch: 192/350 cost: 0.221253514
# Training accuracy: 0.930
# Epoch: 193/350 cost: 0.250838637
# Training accuracy: 0.860
# Epoch: 194/350 cost: 0.219184324
# Training accuracy: 0.930
# Epoch: 195/350 cost: 0.125624299
# Training accuracy: 0.950
# Epoch: 196/350 cost: 0.228737965
# Training accuracy: 0.930
# Epoch: 197/350 cost: 0.312182486
# Training accuracy: 0.890
# Epoch: 198/350 cost: 0.273653269
# Training accuracy: 0.910
# Epoch: 199/350 cost: 0.152918071
# Training accuracy: 0.960
# Epoch: 200/350 cost: 0.266091973
# Training accuracy: 0.890
# Epoch: 201/350 cost: 0.243342936
# Training accuracy: 0.900
# Epoch: 202/350 cost: 0.160261691
# Training accuracy: 0.940
# Epoch: 203/350 cost: 0.196233004
# Training accuracy: 0.910
# Epoch: 204/350 cost: 0.318495780
# Training accuracy: 0.900
# Epoch: 205/350 cost: 0.128579199
# Training accuracy: 0.960
# Epoch: 206/350 cost: 0.270930082
# Training accuracy: 0.920
# Epoch: 207/350 cost: 0.088803776
# Training accuracy: 0.980
# Epoch: 208/350 cost: 0.127279311
# Training accuracy: 0.920
# Epoch: 209/350 cost: 0.184061170
# Training accuracy: 0.930
# Epoch: 210/350 cost: 0.178839982
# Training accuracy: 0.940
# Epoch: 211/350 cost: 0.284594417
# Training accuracy: 0.890
# Epoch: 212/350 cost: 0.165947527
# Training accuracy: 0.920
# Epoch: 213/350 cost: 0.282326609
# Training accuracy: 0.950
# Epoch: 214/350 cost: 0.169187471
# Training accuracy: 0.950
# Epoch: 215/350 cost: 0.169342265
# Training accuracy: 0.950
# Epoch: 216/350 cost: 0.186133802
# Training accuracy: 0.910
# Epoch: 217/350 cost: 0.212485358
# Training accuracy: 0.890
# Epoch: 218/350 cost: 0.170924589
# Training accuracy: 0.930
# Epoch: 219/350 cost: 0.104128815
# Training accuracy: 0.950
# Epoch: 220/350 cost: 0.189243495
# Training accuracy: 0.930
# Epoch: 221/350 cost: 0.279974550
# Training accuracy: 0.880
# Epoch: 222/350 cost: 0.200227082
# Training accuracy: 0.920
# Epoch: 223/350 cost: 0.254557282
# Training accuracy: 0.900
# Epoch: 224/350 cost: 0.180137083
# Training accuracy: 0.930
# Epoch: 225/350 cost: 0.216482788
# Training accuracy: 0.880
# Epoch: 226/350 cost: 0.393097639
# Training accuracy: 0.830
# Epoch: 227/350 cost: 0.188111871
# Training accuracy: 0.940
# Epoch: 228/350 cost: 0.224066198
# Training accuracy: 0.940
# Epoch: 229/350 cost: 0.246030033
# Training accuracy: 0.910
# Epoch: 230/350 cost: 0.217990488
# Training accuracy: 0.930
# Epoch: 231/350 cost: 0.110360324
# Training accuracy: 0.960
# Epoch: 232/350 cost: 0.394876659
# Training accuracy: 0.870
# Epoch: 233/350 cost: 0.319293946
# Training accuracy: 0.900
# Epoch: 234/350 cost: 0.306229651
# Training accuracy: 0.880
# Epoch: 235/350 cost: 0.093427442
# Training accuracy: 0.970
# Epoch: 236/350 cost: 0.211722866
# Training accuracy: 0.910
# Epoch: 237/350 cost: 0.216490015
# Training accuracy: 0.930
# Epoch: 238/350 cost: 0.381236255
# Training accuracy: 0.840
# Epoch: 239/350 cost: 0.419281811
# Training accuracy: 0.830
# Epoch: 240/350 cost: 0.320217431
# Training accuracy: 0.900
# Epoch: 241/350 cost: 0.559863687
# Training accuracy: 0.840
# Epoch: 242/350 cost: 0.581930697
# Training accuracy: 0.890
# Epoch: 243/350 cost: 0.855186105
# Training accuracy: 0.810
# Epoch: 244/350 cost: 0.428439230
# Training accuracy: 0.880
# Epoch: 245/350 cost: 0.371683955
# Training accuracy: 0.920
# Epoch: 246/350 cost: 0.376687467
# Training accuracy: 0.920
# Epoch: 247/350 cost: 0.175559655
# Training accuracy: 0.960
# Epoch: 248/350 cost: 0.411672980
# Training accuracy: 0.860
# Epoch: 249/350 cost: 0.375080675
# Training accuracy: 0.890
# Epoch: 250/350 cost: 0.536459804
# Training accuracy: 0.850
# Epoch: 251/350 cost: 0.364275932
# Training accuracy: 0.850
# Epoch: 252/350 cost: 0.338566780
# Training accuracy: 0.850
# Epoch: 253/350 cost: 0.246150032
# Training accuracy: 0.900
# Epoch: 254/350 cost: 0.384411812
# Training accuracy: 0.860
# Epoch: 255/350 cost: 0.207948506
# Training accuracy: 0.910
# Epoch: 256/350 cost: 0.285711139
# Training accuracy: 0.890
# Epoch: 257/350 cost: 0.433730215
# Training accuracy: 0.820
# Epoch: 258/350 cost: 0.384171188
# Training accuracy: 0.870
# Epoch: 259/350 cost: 0.361022651
# Training accuracy: 0.900
# Epoch: 260/350 cost: 0.522929132
# Training accuracy: 0.790
# Epoch: 261/350 cost: 0.204708233
# Training accuracy: 0.900
# Epoch: 262/350 cost: 0.512363493
# Training accuracy: 0.870
# Epoch: 263/350 cost: 0.538158894
# Training accuracy: 0.900
# Epoch: 264/350 cost: 0.611332476
# Training accuracy: 0.910
# Epoch: 265/350 cost: 0.488201797
# Training accuracy: 0.830
# Epoch: 266/350 cost: 0.405910254
# Training accuracy: 0.890
# Epoch: 267/350 cost: 0.637658596
# Training accuracy: 0.800
# Epoch: 268/350 cost: 0.639786065
# Training accuracy: 0.830
# Epoch: 269/350 cost: 0.407631844
# Training accuracy: 0.860
# Epoch: 270/350 cost: 0.326959968
# Training accuracy: 0.860
# Epoch: 271/350 cost: 0.265991092
# Training accuracy: 0.890
# Epoch: 272/350 cost: 0.208604679
# Training accuracy: 0.940
# Epoch: 273/350 cost: 0.479171574
# Training accuracy: 0.850
# Epoch: 274/350 cost: 0.503324926
# Training accuracy: 0.870
# Epoch: 275/350 cost: 0.578183949
# Training accuracy: 0.870
# Epoch: 276/350 cost: 0.279158026
# Training accuracy: 0.910
# Epoch: 277/350 cost: 0.379490942
# Training accuracy: 0.890
# Epoch: 278/350 cost: 0.443726093
# Training accuracy: 0.900
# Epoch: 279/350 cost: 0.605570495
# Training accuracy: 0.800
# Epoch: 280/350 cost: 0.305046171
# Training accuracy: 0.880
# Epoch: 281/350 cost: 0.401239663
# Training accuracy: 0.850
# Epoch: 282/350 cost: 0.796545327
# Training accuracy: 0.820
# Epoch: 283/350 cost: 0.544612467
# Training accuracy: 0.800
# Epoch: 284/350 cost: 0.709995091
# Training accuracy: 0.770
# Epoch: 285/350 cost: 1.100794792
# Training accuracy: 0.640
# Epoch: 286/350 cost: 0.569720984
# Training accuracy: 0.720
# Epoch: 287/350 cost: 0.439866871
# Training accuracy: 0.860
# Epoch: 288/350 cost: 0.729786515
# Training accuracy: 0.770
# Epoch: 289/350 cost: 0.467589766
# Training accuracy: 0.820
# Epoch: 290/350 cost: 0.581099689
# Training accuracy: 0.850
# Epoch: 291/350 cost: 0.739946604
# Training accuracy: 0.870
# Epoch: 292/350 cost: 0.630763769
# Training accuracy: 0.810
# Epoch: 293/350 cost: 0.868865490
# Training accuracy: 0.730
# Epoch: 294/350 cost: 0.543073297
# Training accuracy: 0.820
# Epoch: 295/350 cost: 0.454597235
# Training accuracy: 0.800
# Epoch: 296/350 cost: 0.428327739
# Training accuracy: 0.860
# Epoch: 297/350 cost: 0.509710312
# Training accuracy: 0.860
# Epoch: 298/350 cost: 0.750741184
# Training accuracy: 0.840
# Epoch: 299/350 cost: 0.989095926
# Training accuracy: 0.800
# Epoch: 300/350 cost: 0.704583824
# Training accuracy: 0.860
# Epoch: 301/350 cost: 0.605251431
# Training accuracy: 0.800
# Epoch: 302/350 cost: 0.357823402
# Training accuracy: 0.880
# Epoch: 303/350 cost: 0.525456429
# Training accuracy: 0.900
# Epoch: 304/350 cost: 0.377557248
# Training accuracy: 0.880
# Epoch: 305/350 cost: 0.510438025
# Training accuracy: 0.880
# Epoch: 306/350 cost: 0.296224564
# Training accuracy: 0.880
# Epoch: 307/350 cost: 0.662479997
# Training accuracy: 0.870
# Epoch: 308/350 cost: 0.616153777
# Training accuracy: 0.820
# Epoch: 309/350 cost: 0.452862144
# Training accuracy: 0.840
# Epoch: 310/350 cost: 0.528741241
# Training accuracy: 0.770
# Epoch: 311/350 cost: 0.310192943
# Training accuracy: 0.870
# Epoch: 312/350 cost: 0.584848106
# Training accuracy: 0.860
# Epoch: 313/350 cost: 0.578316033
# Training accuracy: 0.800
# Epoch: 314/350 cost: 0.244083017
# Training accuracy: 0.880
# Epoch: 315/350 cost: 0.333032429
# Training accuracy: 0.910
# Epoch: 316/350 cost: 0.467580557
# Training accuracy: 0.810
# Epoch: 317/350 cost: 0.517741442
# Training accuracy: 0.840
# Epoch: 318/350 cost: 0.310482264
# Training accuracy: 0.870
# Epoch: 319/350 cost: 0.344736397
# Training accuracy: 0.880
# Epoch: 320/350 cost: 0.393164337
# Training accuracy: 0.860
# Epoch: 321/350 cost: 0.409270853
# Training accuracy: 0.780
# Epoch: 322/350 cost: 0.327403665
# Training accuracy: 0.880
# Epoch: 323/350 cost: 0.370701909
# Training accuracy: 0.850
# Epoch: 324/350 cost: 0.328263849
# Training accuracy: 0.830
# Epoch: 325/350 cost: 0.218290672
# Training accuracy: 0.920
# Epoch: 326/350 cost: 0.194751218
# Training accuracy: 0.930
# Epoch: 327/350 cost: 0.421360701
# Training accuracy: 0.810
# Epoch: 328/350 cost: 0.261091977
# Training accuracy: 0.890
# Epoch: 329/350 cost: 0.268041134
# Training accuracy: 0.910
# Epoch: 330/350 cost: 0.337844133
# Training accuracy: 0.850
# Epoch: 331/350 cost: 0.414207369
# Training accuracy: 0.870
# Epoch: 332/350 cost: 0.206169829
# Training accuracy: 0.960
# Epoch: 333/350 cost: 0.274325222
# Training accuracy: 0.910
# Epoch: 334/350 cost: 0.240366638
# Training accuracy: 0.890
# Epoch: 335/350 cost: 0.503092289
# Training accuracy: 0.850
# Epoch: 336/350 cost: 0.266954154
# Training accuracy: 0.890
# Epoch: 337/350 cost: 0.339026064
# Training accuracy: 0.890
# Epoch: 338/350 cost: 0.367832065
# Training accuracy: 0.810
# Epoch: 339/350 cost: 0.356433630
# Training accuracy: 0.880
# Epoch: 340/350 cost: 0.223812178
# Training accuracy: 0.910
# Epoch: 341/350 cost: 0.217711642
# Training accuracy: 0.930
# Epoch: 342/350 cost: 0.179369062
# Training accuracy: 0.930
# Epoch: 343/350 cost: 0.428164601
# Training accuracy: 0.870
# Epoch: 344/350 cost: 0.253142178
# Training accuracy: 0.950
# Epoch: 345/350 cost: 0.353344083
# Training accuracy: 0.910
# Epoch: 346/350 cost: 0.254503220
# Training accuracy: 0.900
# Epoch: 347/350 cost: 0.216404110
# Training accuracy: 0.860
# Epoch: 348/350 cost: 0.339826405
# Training accuracy: 0.870
# Epoch: 349/350 cost: 0.249726832
# Training accuracy: 0.890
# 訓練完成
# 開始測試...
#
# Test accuracy: 0.773
# Session closed!

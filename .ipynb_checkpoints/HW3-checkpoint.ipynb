# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt

FILE_PATH = 'letterdata.csv'                                # csv path
raw_data = pd.read_csv(FILE_PATH)						    

print("Raw data loaded successfully...\n")
#------------------------------------------------------------------------------
# 參數

Y_LABEL = 'letter'                                   		    	# 結果label
KEYS = [i for i in raw_data.keys().tolist() if i != Y_LABEL]	# 用來運算預測的key
N_INSTANCES = raw_data.shape[0]                     			# Number of instances
N_INPUT = raw_data.shape[1] - 1                     			# Input size
N_CLASSES = 26                                                   # 類型數
TEST_SIZE = 0.1                                    			    # 測試數
TRAIN_SIZE = int(N_INSTANCES * (1 - TEST_SIZE))     			# 訓練大小
LEARNING_RATE = 0.001                              			    # 學習rate
TRAINING_EPOCHS = 300                               			# epochs
BATCH_SIZE = 100                                    			# Batch size
DISPLAY_STEP = 1                                    			# Display progress each x epochs
HIDDEN_SIZE = 350	                                   	    	# Number of hidden neurons
STDDEV = 0.1                                        			# Standard deviation (for weights random init)
RANDOM_STATE = 100 									            # Random state for train_test_split

#------------------------------------------------------------------------------
# Loading data

# Load data
data = raw_data[KEYS].get_values()                  			        # X data
labels = [ord( i ) - ord('A') for i in raw_data[Y_LABEL].get_values()]  # y data
# One hot encoding for labels
labels_ = np.zeros((N_INSTANCES, N_CLASSES))
labels_[np.arange(N_INSTANCES), labels] = 1

# Train-test split
data_train, data_test, labels_train, labels_test = train_test_split(data,
                                                                    labels_,
                                                                    test_size = TEST_SIZE,
                                                                    random_state = RANDOM_STATE)

print("讀取完畢 檔案分割成功\n")
#------------------------------------------------------------------------------
#神經網路架構

# Tf placeholders
X = tf.placeholder(tf.float32, [None, N_INPUT])
y = tf.placeholder(tf.float32, [None, N_CLASSES])
dropout_keep_prob = tf.placeholder(tf.float32)

# 自定義層次函數
def layer(output_dim, input_dim, inputs, activation = None):
    W = tf.Variable(tf.random_normal([input_dim, output_dim]))
    b = tf.Variable(tf.random_normal([1, output_dim]))
    XWb = tf.matmul(inputs, W) + b
    if activation is None:
        outputs = XWb
    else:
        outputs = activation(XWb)
    return outputs

# Build model
h1 = layer(output_dim = HIDDEN_SIZE, input_dim = N_INPUT, inputs = X, activation = tf.nn.tanh)
h2 = layer(output_dim = HIDDEN_SIZE, input_dim = HIDDEN_SIZE, inputs = h1, activation = tf.nn.tanh)
h3 = layer(output_dim = HIDDEN_SIZE, input_dim = HIDDEN_SIZE, inputs = h2, activation = tf.nn.tanh)
pred = layer(output_dim = N_CLASSES, input_dim = HIDDEN_SIZE, inputs = h3, activation = None)
#loss以及優化公式
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = pred, labels = y))
optimizer = tf.train.AdamOptimizer(learning_rate = LEARNING_RATE).minimize(cost)

#計算正確率
correct_prediction = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

#初始化
init = tf.initialize_all_variables()
#------------------------------------------------------------------------------
#設置GPU運算
#tf.device('/gpu:0')


#------------------------------------------------------------------------------
# Training
print("開始訓練\n")
#sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))    #Print log
sess = tf.Session()
sess.run(init)
loss_list = []
epoch_list = []
accuracy_list = []

#訓練迴圈
for epoch in range(TRAINING_EPOCHS):
    avg_cost = 0.
    total_batch = int(data_train.shape[0] / BATCH_SIZE)
    #batches
    for i in range(total_batch):
        randidx = np.random.randint(int(TRAIN_SIZE), size = BATCH_SIZE)
        batch_xs = data_train[randidx, :]
        batch_ys = labels_train[randidx, :]
        #優化
        sess.run(optimizer, feed_dict={X: batch_xs, y: batch_ys, dropout_keep_prob: 0.9})
        #平均loss
        avg_cost += sess.run(cost, feed_dict={X: batch_xs, y: batch_ys, dropout_keep_prob:1.})/total_batch
    #log
    if epoch % DISPLAY_STEP == 0:
        print ("Epoch: %03d/%03d cost: %.9f" % (epoch, TRAINING_EPOCHS, avg_cost))
        train_acc = sess.run(accuracy, feed_dict={X: batch_xs, y: batch_ys, dropout_keep_prob:1.})
        print ("Training accuracy: %.3f" % (train_acc))
        epoch_list.append(epoch)
        loss_list.append(avg_cost)
        accuracy_list.append(train_acc)



print ("訓練完成")
print("開始測試...\n")
#------------------------------------------------------------------------------
# Testing

test_acc = sess.run(accuracy, feed_dict={X: data_test, y: labels_test, dropout_keep_prob:1.})
print ("Test accuracy: %.3f" % (test_acc))

sess.close()
print("Session closed!")

#顯示曲線圖
#%matplotlib inline
fig = plt.gcf()
fig.set_size_inches(5, 3)
plt.plot(epoch_list, loss_list, label = 'loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc = 'upper right')
plt.show()

fig = plt.gcf()
fig.set_size_inches(5, 3)
plt.plot(epoch_list, accuracy_list, label = 'accuracy')

plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy'], loc = 'upper left')
plt.show()
# Out:
# Raw data loaded successfully...
#
# 讀取完畢 檔案分割成功
#
# 開始訓練
#
# Epoch: 000/300 cost: 16.886281003
# Training accuracy: 0.230
# Epoch: 001/300 cost: 8.795576610
# Training accuracy: 0.430
# Epoch: 002/300 cost: 6.340027859
# Training accuracy: 0.460
# Epoch: 003/300 cost: 5.131947702
# Training accuracy: 0.580
# Epoch: 004/300 cost: 4.280951909
# Training accuracy: 0.570
# Epoch: 005/300 cost: 3.834094180
# Training accuracy: 0.520
# Epoch: 006/300 cost: 3.399380609
# Training accuracy: 0.670
# Epoch: 007/300 cost: 3.077723808
# Training accuracy: 0.580
# Epoch: 008/300 cost: 2.769529110
# Training accuracy: 0.690
# Epoch: 009/300 cost: 2.522168069
# Training accuracy: 0.580
# Epoch: 010/300 cost: 2.350442646
# Training accuracy: 0.600
# Epoch: 011/300 cost: 2.140801769
# Training accuracy: 0.710
# Epoch: 012/300 cost: 2.103732506
# Training accuracy: 0.620
# Epoch: 013/300 cost: 1.932094328
# Training accuracy: 0.740
# Epoch: 014/300 cost: 1.746649303
# Training accuracy: 0.680
# Epoch: 015/300 cost: 1.665351756
# Training accuracy: 0.740
# Epoch: 016/300 cost: 1.563955364
# Training accuracy: 0.750
# Epoch: 017/300 cost: 1.490162559
# Training accuracy: 0.700
# Epoch: 018/300 cost: 1.451346502
# Training accuracy: 0.740
# Epoch: 019/300 cost: 1.391711348
# Training accuracy: 0.730
# Epoch: 020/300 cost: 1.327063839
# Training accuracy: 0.640
# Epoch: 021/300 cost: 1.300182659
# Training accuracy: 0.710
# Epoch: 022/300 cost: 1.194013190
# Training accuracy: 0.670
# Epoch: 023/300 cost: 1.149187152
# Training accuracy: 0.780
# Epoch: 024/300 cost: 1.120483363
# Training accuracy: 0.750
# Epoch: 025/300 cost: 1.060518279
# Training accuracy: 0.810
# Epoch: 026/300 cost: 1.065566185
# Training accuracy: 0.760
# Epoch: 027/300 cost: 1.005837988
# Training accuracy: 0.710
# Epoch: 028/300 cost: 0.956942965
# Training accuracy: 0.740
# Epoch: 029/300 cost: 0.963892035
# Training accuracy: 0.710
# Epoch: 030/300 cost: 0.914330775
# Training accuracy: 0.820
# Epoch: 031/300 cost: 0.885175773
# Training accuracy: 0.690
# Epoch: 032/300 cost: 0.877975865
# Training accuracy: 0.800
# Epoch: 033/300 cost: 0.844345680
# Training accuracy: 0.780
# Epoch: 034/300 cost: 0.844682148
# Training accuracy: 0.830
# Epoch: 035/300 cost: 0.826677551
# Training accuracy: 0.790
# Epoch: 036/300 cost: 0.800286254
# Training accuracy: 0.810
# Epoch: 037/300 cost: 0.781907248
# Training accuracy: 0.840
# Epoch: 038/300 cost: 0.747288441
# Training accuracy: 0.710
# Epoch: 039/300 cost: 0.743905703
# Training accuracy: 0.800
# Epoch: 040/300 cost: 0.746236013
# Training accuracy: 0.820
# Epoch: 041/300 cost: 0.725297172
# Training accuracy: 0.810
# Epoch: 042/300 cost: 0.723931879
# Training accuracy: 0.830
# Epoch: 043/300 cost: 0.660313883
# Training accuracy: 0.810
# Epoch: 044/300 cost: 0.669330584
# Training accuracy: 0.740
# Epoch: 045/300 cost: 0.688119817
# Training accuracy: 0.890
# Epoch: 046/300 cost: 0.673239064
# Training accuracy: 0.810
# Epoch: 047/300 cost: 0.644932991
# Training accuracy: 0.780
# Epoch: 048/300 cost: 0.630710441
# Training accuracy: 0.880
# Epoch: 049/300 cost: 0.610607105
# Training accuracy: 0.800
# Epoch: 050/300 cost: 0.596762982
# Training accuracy: 0.880
# Epoch: 051/300 cost: 0.597194524
# Training accuracy: 0.850
# Epoch: 052/300 cost: 0.581339774
# Training accuracy: 0.830
# Epoch: 053/300 cost: 0.584048432
# Training accuracy: 0.910
# Epoch: 054/300 cost: 0.569503333
# Training accuracy: 0.820
# Epoch: 055/300 cost: 0.535798479
# Training accuracy: 0.830
# Epoch: 056/300 cost: 0.543950080
# Training accuracy: 0.820
# Epoch: 057/300 cost: 0.555038151
# Training accuracy: 0.850
# Epoch: 058/300 cost: 0.550384869
# Training accuracy: 0.870
# Epoch: 059/300 cost: 0.546697243
# Training accuracy: 0.780
# Epoch: 060/300 cost: 0.573041700
# Training accuracy: 0.830
# Epoch: 061/300 cost: 0.520465721
# Training accuracy: 0.810
# Epoch: 062/300 cost: 0.520251218
# Training accuracy: 0.830
# Epoch: 063/300 cost: 0.528784636
# Training accuracy: 0.840
# Epoch: 064/300 cost: 0.519162864
# Training accuracy: 0.880
# Epoch: 065/300 cost: 0.502159504
# Training accuracy: 0.890
# Epoch: 066/300 cost: 0.482939740
# Training accuracy: 0.870
# Epoch: 067/300 cost: 0.458476678
# Training accuracy: 0.820
# Epoch: 068/300 cost: 0.458833135
# Training accuracy: 0.900
# Epoch: 069/300 cost: 0.459100120
# Training accuracy: 0.860
# Epoch: 070/300 cost: 0.435340510
# Training accuracy: 0.880
# Epoch: 071/300 cost: 0.449156906
# Training accuracy: 0.790
# Epoch: 072/300 cost: 0.468417715
# Training accuracy: 0.860
# Epoch: 073/300 cost: 0.467630411
# Training accuracy: 0.820
# Epoch: 074/300 cost: 0.420872884
# Training accuracy: 0.890
# Epoch: 075/300 cost: 0.430158251
# Training accuracy: 0.850
# Epoch: 076/300 cost: 0.403701288
# Training accuracy: 0.790
# Epoch: 077/300 cost: 0.389465522
# Training accuracy: 0.900
# Epoch: 078/300 cost: 0.408374876
# Training accuracy: 0.910
# Epoch: 079/300 cost: 0.406150088
# Training accuracy: 0.890
# Epoch: 080/300 cost: 0.381043311
# Training accuracy: 0.930
# Epoch: 081/300 cost: 0.377925122
# Training accuracy: 0.910
# Epoch: 082/300 cost: 0.389983878
# Training accuracy: 0.870
# Epoch: 083/300 cost: 0.405275377
# Training accuracy: 0.870
# Epoch: 084/300 cost: 0.415959966
# Training accuracy: 0.850
# Epoch: 085/300 cost: 0.410742809
# Training accuracy: 0.840
# Epoch: 086/300 cost: 0.404845902
# Training accuracy: 0.870
# Epoch: 087/300 cost: 0.376311824
# Training accuracy: 0.900
# Epoch: 088/300 cost: 0.383582349
# Training accuracy: 0.920
# Epoch: 089/300 cost: 0.375065365
# Training accuracy: 0.900
# Epoch: 090/300 cost: 0.387293164
# Training accuracy: 0.930
# Epoch: 091/300 cost: 0.400595226
# Training accuracy: 0.920
# Epoch: 092/300 cost: 0.364115808
# Training accuracy: 0.870
# Epoch: 093/300 cost: 0.358097813
# Training accuracy: 0.830
# Epoch: 094/300 cost: 0.345478117
# Training accuracy: 0.920
# Epoch: 095/300 cost: 0.327626640
# Training accuracy: 0.900
# Epoch: 096/300 cost: 0.326799371
# Training accuracy: 0.880
# Epoch: 097/300 cost: 0.340222550
# Training accuracy: 0.910
# Epoch: 098/300 cost: 0.331825083
# Training accuracy: 0.950
# Epoch: 099/300 cost: 0.327405382
# Training accuracy: 0.870
# Epoch: 100/300 cost: 0.320241210
# Training accuracy: 0.910
# Epoch: 101/300 cost: 0.330748623
# Training accuracy: 0.890
# Epoch: 102/300 cost: 0.330481480
# Training accuracy: 0.910
# Epoch: 103/300 cost: 0.332920584
# Training accuracy: 0.920
# Epoch: 104/300 cost: 0.308074733
# Training accuracy: 0.880
# Epoch: 105/300 cost: 0.312168759
# Training accuracy: 0.940
# Epoch: 106/300 cost: 0.300703742
# Training accuracy: 0.930
# Epoch: 107/300 cost: 0.295596634
# Training accuracy: 0.920
# Epoch: 108/300 cost: 0.297405205
# Training accuracy: 0.910
# Epoch: 109/300 cost: 0.308392650
# Training accuracy: 0.900
# Epoch: 110/300 cost: 0.307189282
# Training accuracy: 0.900
# Epoch: 111/300 cost: 0.302425730
# Training accuracy: 0.900
# Epoch: 112/300 cost: 0.286472973
# Training accuracy: 0.900
# Epoch: 113/300 cost: 0.282434481
# Training accuracy: 0.870
# Epoch: 114/300 cost: 0.288442339
# Training accuracy: 0.910
# Epoch: 115/300 cost: 0.303245162
# Training accuracy: 0.920
# Epoch: 116/300 cost: 0.293462577
# Training accuracy: 0.900
# Epoch: 117/300 cost: 0.291263281
# Training accuracy: 0.960
# Epoch: 118/300 cost: 0.278955477
# Training accuracy: 0.960
# Epoch: 119/300 cost: 0.282887365
# Training accuracy: 0.920
# Epoch: 120/300 cost: 0.278725412
# Training accuracy: 0.930
# Epoch: 121/300 cost: 0.281333928
# Training accuracy: 0.920
# Epoch: 122/300 cost: 0.283915171
# Training accuracy: 0.930
# Epoch: 123/300 cost: 0.276352022
# Training accuracy: 0.870
# Epoch: 124/300 cost: 0.265281533
# Training accuracy: 0.880
# Epoch: 125/300 cost: 0.258912443
# Training accuracy: 0.840
# Epoch: 126/300 cost: 0.249057136
# Training accuracy: 0.880
# Epoch: 127/300 cost: 0.243998107
# Training accuracy: 0.940
# Epoch: 128/300 cost: 0.255803554
# Training accuracy: 0.900
# Epoch: 129/300 cost: 0.247917526
# Training accuracy: 0.930
# Epoch: 130/300 cost: 0.235381436
# Training accuracy: 0.960
# Epoch: 131/300 cost: 0.245218897
# Training accuracy: 0.900
# Epoch: 132/300 cost: 0.233872428
# Training accuracy: 0.940
# Epoch: 133/300 cost: 0.242151462
# Training accuracy: 0.940
# Epoch: 134/300 cost: 0.267152582
# Training accuracy: 0.890
# Epoch: 135/300 cost: 0.261936114
# Training accuracy: 0.940
# Epoch: 136/300 cost: 0.260428014
# Training accuracy: 0.910
# Epoch: 137/300 cost: 0.264844978
# Training accuracy: 0.910
# Epoch: 138/300 cost: 0.277847652
# Training accuracy: 0.870
# Epoch: 139/300 cost: 0.239352067
# Training accuracy: 0.890
# Epoch: 140/300 cost: 0.238769855
# Training accuracy: 0.920
# Epoch: 141/300 cost: 0.229784790
# Training accuracy: 0.910
# Epoch: 142/300 cost: 0.218270545
# Training accuracy: 0.950
# Epoch: 143/300 cost: 0.224972475
# Training accuracy: 0.920
# Epoch: 144/300 cost: 0.225737021
# Training accuracy: 0.940
# Epoch: 145/300 cost: 0.223033363
# Training accuracy: 0.930
# Epoch: 146/300 cost: 0.240338753
# Training accuracy: 0.950
# Epoch: 147/300 cost: 0.235431531
# Training accuracy: 0.950
# Epoch: 148/300 cost: 0.232653117
# Training accuracy: 0.870
# Epoch: 149/300 cost: 0.229665178
# Training accuracy: 0.930
# Epoch: 150/300 cost: 0.237257412
# Training accuracy: 0.900
# Epoch: 151/300 cost: 0.232186474
# Training accuracy: 0.950
# Epoch: 152/300 cost: 0.223155928
# Training accuracy: 0.930
# Epoch: 153/300 cost: 0.211288216
# Training accuracy: 0.960
# Epoch: 154/300 cost: 0.222191462
# Training accuracy: 0.910
# Epoch: 155/300 cost: 0.219811820
# Training accuracy: 0.940
# Epoch: 156/300 cost: 0.219452793
# Training accuracy: 0.940
# Epoch: 157/300 cost: 0.221890600
# Training accuracy: 0.940
# Epoch: 158/300 cost: 0.222630934
# Training accuracy: 0.900
# Epoch: 159/300 cost: 0.226530430
# Training accuracy: 0.960
# Epoch: 160/300 cost: 0.213571584
# Training accuracy: 0.910
# Epoch: 161/300 cost: 0.204311278
# Training accuracy: 0.910
# Epoch: 162/300 cost: 0.196063761
# Training accuracy: 0.930
# Epoch: 163/300 cost: 0.207346272
# Training accuracy: 0.960
# Epoch: 164/300 cost: 0.199754793
# Training accuracy: 0.910
# Epoch: 165/300 cost: 0.189909675
# Training accuracy: 0.930
# Epoch: 166/300 cost: 0.187573867
# Training accuracy: 0.960
# Epoch: 167/300 cost: 0.189555872
# Training accuracy: 0.930
# Epoch: 168/300 cost: 0.197974980
# Training accuracy: 0.970
# Epoch: 169/300 cost: 0.197269041
# Training accuracy: 0.940
# Epoch: 170/300 cost: 0.186000867
# Training accuracy: 0.950
# Epoch: 171/300 cost: 0.171811264
# Training accuracy: 0.960
# Epoch: 172/300 cost: 0.186150373
# Training accuracy: 0.940
# Epoch: 173/300 cost: 0.177758172
# Training accuracy: 0.980
# Epoch: 174/300 cost: 0.174830378
# Training accuracy: 0.950
# Epoch: 175/300 cost: 0.194841400
# Training accuracy: 0.960
# Epoch: 176/300 cost: 0.171247569
# Training accuracy: 0.950
# Epoch: 177/300 cost: 0.184224734
# Training accuracy: 0.920
# Epoch: 178/300 cost: 0.185464510
# Training accuracy: 0.900
# Epoch: 179/300 cost: 0.185558299
# Training accuracy: 0.920
# Epoch: 180/300 cost: 0.181514910
# Training accuracy: 0.950
# Epoch: 181/300 cost: 0.175000445
# Training accuracy: 0.920
# Epoch: 182/300 cost: 0.177333761
# Training accuracy: 0.920
# Epoch: 183/300 cost: 0.180233186
# Training accuracy: 0.960
# Epoch: 184/300 cost: 0.172553946
# Training accuracy: 0.940
# Epoch: 185/300 cost: 0.177623952
# Training accuracy: 0.940
# Epoch: 186/300 cost: 0.167620487
# Training accuracy: 0.920
# Epoch: 187/300 cost: 0.158939170
# Training accuracy: 0.940
# Epoch: 188/300 cost: 0.170456533
# Training accuracy: 0.930
# Epoch: 189/300 cost: 0.153884540
# Training accuracy: 0.970
# Epoch: 190/300 cost: 0.161439745
# Training accuracy: 0.870
# Epoch: 191/300 cost: 0.154625774
# Training accuracy: 0.950
# Epoch: 192/300 cost: 0.166733496
# Training accuracy: 0.930
# Epoch: 193/300 cost: 0.160737780
# Training accuracy: 0.960
# Epoch: 194/300 cost: 0.153085275
# Training accuracy: 0.950
# Epoch: 195/300 cost: 0.167775422
# Training accuracy: 0.940
# Epoch: 196/300 cost: 0.158225746
# Training accuracy: 0.940
# Epoch: 197/300 cost: 0.160922367
# Training accuracy: 0.920
# Epoch: 198/300 cost: 0.167095842
# Training accuracy: 0.950
# Epoch: 199/300 cost: 0.169300151
# Training accuracy: 0.950
# Epoch: 200/300 cost: 0.173938270
# Training accuracy: 0.960
# Epoch: 201/300 cost: 0.172706144
# Training accuracy: 0.930
# Epoch: 202/300 cost: 0.164290985
# Training accuracy: 0.930
# Epoch: 203/300 cost: 0.153715930
# Training accuracy: 0.950
# Epoch: 204/300 cost: 0.155547066
# Training accuracy: 0.980
# Epoch: 205/300 cost: 0.159888849
# Training accuracy: 0.970
# Epoch: 206/300 cost: 0.153152078
# Training accuracy: 0.930
# Epoch: 207/300 cost: 0.145899508
# Training accuracy: 1.000
# Epoch: 208/300 cost: 0.140221658
# Training accuracy: 0.940
# Epoch: 209/300 cost: 0.143999892
# Training accuracy: 0.960
# Epoch: 210/300 cost: 0.138869566
# Training accuracy: 0.950
# Epoch: 211/300 cost: 0.156382313
# Training accuracy: 0.950
# Epoch: 212/300 cost: 0.153764592
# Training accuracy: 0.920
# Epoch: 213/300 cost: 0.168611338
# Training accuracy: 0.950
# Epoch: 214/300 cost: 0.173921770
# Training accuracy: 0.960
# Epoch: 215/300 cost: 0.177669429
# Training accuracy: 0.940
# Epoch: 216/300 cost: 0.153625231
# Training accuracy: 0.940
# Epoch: 217/300 cost: 0.152728204
# Training accuracy: 0.980
# Epoch: 218/300 cost: 0.141724536
# Training accuracy: 0.950
# Epoch: 219/300 cost: 0.145703774
# Training accuracy: 0.980
# Epoch: 220/300 cost: 0.156119949
# Training accuracy: 0.930
# Epoch: 221/300 cost: 0.150947344
# Training accuracy: 0.910
# Epoch: 222/300 cost: 0.143893469
# Training accuracy: 0.970
# Epoch: 223/300 cost: 0.149949417
# Training accuracy: 0.980
# Epoch: 224/300 cost: 0.160825441
# Training accuracy: 0.910
# Epoch: 225/300 cost: 0.154692195
# Training accuracy: 0.980
# Epoch: 226/300 cost: 0.142908451
# Training accuracy: 0.990
# Epoch: 227/300 cost: 0.139666672
# Training accuracy: 0.960
# Epoch: 228/300 cost: 0.127335392
# Training accuracy: 0.990
# Epoch: 229/300 cost: 0.140245045
# Training accuracy: 0.960
# Epoch: 230/300 cost: 0.135739155
# Training accuracy: 0.940
# Epoch: 231/300 cost: 0.132313419
# Training accuracy: 0.900
# Epoch: 232/300 cost: 0.124096873
# Training accuracy: 0.960
# Epoch: 233/300 cost: 0.130803495
# Training accuracy: 0.990
# Epoch: 234/300 cost: 0.131739501
# Training accuracy: 0.980
# Epoch: 235/300 cost: 0.115454939
# Training accuracy: 0.970
# Epoch: 236/300 cost: 0.117793226
# Training accuracy: 0.980
# Epoch: 237/300 cost: 0.126035053
# Training accuracy: 0.970
# Epoch: 238/300 cost: 0.112766709
# Training accuracy: 0.930
# Epoch: 239/300 cost: 0.125999112
# Training accuracy: 0.970
# Epoch: 240/300 cost: 0.127328996
# Training accuracy: 0.920
# Epoch: 241/300 cost: 0.137781864
# Training accuracy: 0.970
# Epoch: 242/300 cost: 0.138828086
# Training accuracy: 0.930
# Epoch: 243/300 cost: 0.140850452
# Training accuracy: 0.930
# Epoch: 244/300 cost: 0.123787339
# Training accuracy: 0.990
# Epoch: 245/300 cost: 0.134826373
# Training accuracy: 0.950
# Epoch: 246/300 cost: 0.127791678
# Training accuracy: 0.970
# Epoch: 247/300 cost: 0.127888937
# Training accuracy: 0.980
# Epoch: 248/300 cost: 0.122599745
# Training accuracy: 0.930
# Epoch: 249/300 cost: 0.118194569
# Training accuracy: 0.940
# Epoch: 250/300 cost: 0.117651880
# Training accuracy: 0.970
# Epoch: 251/300 cost: 0.123567055
# Training accuracy: 0.940
# Epoch: 252/300 cost: 0.120955899
# Training accuracy: 0.940
# Epoch: 253/300 cost: 0.117084681
# Training accuracy: 0.950
# Epoch: 254/300 cost: 0.105574640
# Training accuracy: 0.930
# Epoch: 255/300 cost: 0.105558141
# Training accuracy: 0.990
# Epoch: 256/300 cost: 0.109828227
# Training accuracy: 0.980
# Epoch: 257/300 cost: 0.104542990
# Training accuracy: 0.950
# Epoch: 258/300 cost: 0.110466023
# Training accuracy: 0.990
# Epoch: 259/300 cost: 0.099497503
# Training accuracy: 0.950
# Epoch: 260/300 cost: 0.124770242
# Training accuracy: 0.950
# Epoch: 261/300 cost: 0.122399576
# Training accuracy: 0.970
# Epoch: 262/300 cost: 0.127804319
# Training accuracy: 0.950
# Epoch: 263/300 cost: 0.122760843
# Training accuracy: 0.950
# Epoch: 264/300 cost: 0.124377723
# Training accuracy: 0.930
# Epoch: 265/300 cost: 0.114991870
# Training accuracy: 0.940
# Epoch: 266/300 cost: 0.099496760
# Training accuracy: 0.960
# Epoch: 267/300 cost: 0.110803664
# Training accuracy: 0.970
# Epoch: 268/300 cost: 0.114216062
# Training accuracy: 0.960
# Epoch: 269/300 cost: 0.106990009
# Training accuracy: 0.960
# Epoch: 270/300 cost: 0.112571942
# Training accuracy: 0.980
# Epoch: 271/300 cost: 0.106576300
# Training accuracy: 0.970
# Epoch: 272/300 cost: 0.114501221
# Training accuracy: 0.970
# Epoch: 273/300 cost: 0.107715060
# Training accuracy: 1.000
# Epoch: 274/300 cost: 0.103157121
# Training accuracy: 0.960
# Epoch: 275/300 cost: 0.121309921
# Training accuracy: 0.950
# Epoch: 276/300 cost: 0.109901254
# Training accuracy: 0.940
# Epoch: 277/300 cost: 0.095907171
# Training accuracy: 0.990
# Epoch: 278/300 cost: 0.096303674
# Training accuracy: 0.960
# Epoch: 279/300 cost: 0.105360944
# Training accuracy: 0.990
# Epoch: 280/300 cost: 0.095688084
# Training accuracy: 0.970
# Epoch: 281/300 cost: 0.099278958
# Training accuracy: 0.970
# Epoch: 282/300 cost: 0.108503031
# Training accuracy: 0.970
# Epoch: 283/300 cost: 0.093163297
# Training accuracy: 0.960
# Epoch: 284/300 cost: 0.099175384
# Training accuracy: 0.960
# Epoch: 285/300 cost: 0.115097774
# Training accuracy: 0.990
# Epoch: 286/300 cost: 0.100856159
# Training accuracy: 0.980
# Epoch: 287/300 cost: 0.095758392
# Training accuracy: 0.960
# Epoch: 288/300 cost: 0.105352407
# Training accuracy: 1.000
# Epoch: 289/300 cost: 0.098960870
# Training accuracy: 0.970
# Epoch: 290/300 cost: 0.110698454
# Training accuracy: 0.950
# Epoch: 291/300 cost: 0.106754892
# Training accuracy: 0.980
# Epoch: 292/300 cost: 0.102555980
# Training accuracy: 0.980
# Epoch: 293/300 cost: 0.104462585
# Training accuracy: 0.970
# Epoch: 294/300 cost: 0.101995067
# Training accuracy: 0.950
# Epoch: 295/300 cost: 0.116646797
# Training accuracy: 0.920
# Epoch: 296/300 cost: 0.105660222
# Training accuracy: 0.960
# Epoch: 297/300 cost: 0.105733790
# Training accuracy: 0.970
# Epoch: 298/300 cost: 0.094188661
# Training accuracy: 0.960
# Epoch: 299/300 cost: 0.098980563
# Training accuracy: 0.970
# 訓練完成
#
# 開始測試...
#
# Test accuracy: 0.918
# Session closed!
